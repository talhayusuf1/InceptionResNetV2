# %%
import numpy as np
from PIL import Image #İstenilen resimin pikselini degistirir
from IPython.display import Image as show_image
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input,decode_predictions

# %%
img = Image.open('submarine.jpg').resize((299,299))

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (299, 299, 3)

# %%
print(img.ndim)
# Out:
# 3

# %%
img = img.reshape(-1,299,299,3)#bir boyut daha kattık çünkü model 4 boyutlu calısıyor

# %%
print(img.ndim)
# Out:
# 4

# %%
img = preprocess_input(img)

# %%
incresv2_model = InceptionResNetV2(weights ='imagenet',classes = 1000)

# %%
print(incresv2_model.summary())
print(type(incresv2_model))
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
show_image(filename='submarine.jpg')

# %%
preds = incresv2_model.predict(img)
print('Predicted categories: ', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted categories:  [('n04347754', 'submarine', 0.97399455), ('n03773504', 'missile', 0.00015363439), ('n03804744', 'nail', 0.00013916743)]
